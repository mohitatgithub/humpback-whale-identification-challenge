# %% [markdown]
# ### Introduction
#
# To aid whale conservation efforts, scientists use photo surveillance systems to monitor ocean activity. They use the shape of whales’ tails and unique markings found in footage to identify what species of whale they’re analyzing and meticulously log whale pod dynamics and movements. For the past 40 years, most of this work has been done manually by individual scientists, leaving a huge trove of data untapped and underutilized.
#
# In this competition, we were challenged to build an algorithm to identifying whale species in images gathered from research institutions and public contributors.

# %% [markdown]
# ### Exploratory Analysis

# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")

# %%
train.head()
# Out:
#           Image         Id
# 0  00022e1a.jpg  w_e15442c
# 1  000466c4.jpg  w_1287fbc
# 2  00087b01.jpg  w_da2efe0
# 3  001296d5.jpg  w_19e5482
# 4  0014cfdf.jpg  w_f22f3e3

# %%
train.shape
# Out:
# (9850, 2)

# %%
len(train['Id'].unique().tolist())
#Too many different classes! Lets check number of samples in each class
# Out:
# 4251

# %%
train.groupby('Id').count().sort_values(['Image'], ascending=False)
#Less then 35 pictures are available for 4250 whale categories and many whale categories have only 1 picture lets count these.
# Out:
#            Image
# Id
# new_whale    810
# w_1287fbc     34
# w_98baff9     27
# w_7554f44     26
# w_1eafe46     23
# w_fd1cb9d     22
# w_ab4cae2     22
# w_693c9ee     22
# w_987a36f     21
# w_43be268     21
# w_73d5489     21
# w_f19faeb     20
# w_95874a5     19
# w_9b401eb     19
# w_c0d494d     18
# w_b7d5069     18
# w_0e737d0     17
# w_eb0a6ed     17
# w_dbda0d6     17
# w_18eee6e     17
# w_17ee910     16
# w_a59905f     16
# w_6c803bf     16
# w_b0e05b1     16
# w_67de30b     16
# w_9ca943b     15
# w_89e159a     15
# w_ee17a08     15
# w_cae7677     15
# w_2d99a0c     14
# ...          ...
# w_7f81ba5      1
# w_7f867ec      1
# w_7fc15e6      1
# w_7fe3551      1
# w_800034f      1
# w_80171b9      1
# w_80211fd      1
# w_0fe48f3      1
# w_7eb2c7c      1
# w_7e9e89f      1
# w_7e9dc07      1
# w_7e8fb79      1
# w_7c7bfb0      1
# w_7c8620c      1
# w_7c979d9      1
# w_7ca11d6      1
# w_7caa4fe      1
# w_7cc620b      1
# w_7d19608      1
# w_7d2d70c      1
# ...

# %%
temp_df = train.groupby('Id').count()

# %%
temp_df_subset = temp_df[temp_df.Image == 1]

# %%
temp_df_subset.shape
#2220 out of 4251 whale categories have only 1 image available in training data, 
#we can either drop these images or try using good data augmentation techniques.
# Out:
# (2220, 1)

# %% [markdown]
# ### Image Data Import

# %%
#Function to read images as arrays
def read_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_COLOR)
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    #img = cv2.resize(img, (64,64))
    return img

# %%
#Reading all training images in a python lists
train_data = []
train_labels = train['Id'].values

for img in tqdm(train['Image'].values):
    train_data.append(read_image('/media/newhd/Data Science/Challenges/kaggle_Humpback Whale Identification Challenge/train'.format(img)))
# Out:
# 100%|██████████| 9850/9850 [00:00<00:00, 195345.87it/s]

# %%
##Lets see the images with their respective labels
plt.rc('axes', grid=False)

_, axs = plt.subplots(4,4, sharex = 'col', sharey='row', figsize = (12,12))
axs = axs.ravel()

#Lets see first 16 images
for i, (image_name, label) in enumerate(zip(train.Image, train.Id)):
    if i <= 15:
        img = read_image('/media/newhd/Data Science/Challenges/kaggle_Humpback Whale Identification Challenge/train/' + image_name)
        axs[i].imshow(img)
        axs[i].set_title('{}'.format(label))
    else:
        break

# %% [markdown]
# ### Data Augmentation

# %%
from keras.preprocessing.image import (
    random_rotation, random_shift, random_shear, random_zoom,
    random_channel_shift, transform_matrix_offset_center, img_to_array)
from PIL import Image

# %%
def plot_images(imgs, labels, rows=4):
    figure = plt.figure(figsize=(13, 8))

    cols = len(imgs) // rows + 1

    for i in range(len(imgs)):
        subplot = figure.add_subplot(rows, cols, i + 1)
        subplot.axis('Off')
        if labels:
            subplot.set_title(labels[i], fontsize=16)
        plt.imshow(imgs[i], cmap='gray')

# %%
img = Image.open(f'train/ff6946b4.jpg')

# %%
img_arr = img_to_array(img)

# %%
plt.imshow(img)

# %% [markdown]
# **Augmenting Image**

# %%
#Random Rotation
imgs = [random_rotation(img_arr, 30, row_axis=0, col_axis=1, channel_axis=2, fill_mode='nearest') * 255 for _ in range(3)]
plot_images(imgs, None, rows=1)

#Random Shift
imgs = [random_shift(img_arr, wrg=0.1, hrg=0.3, row_axis=0, col_axis=1, channel_axis=2, fill_mode='nearest') * 255 for _ in range(3)]
plot_images(imgs, None, rows=1)

#Random Shear
imgs = [random_shear(img_arr, intensity=0.4, row_axis=0, col_axis=1, channel_axis=2, fill_mode='nearest') * 255 for _ in range(3)]
plot_images(imgs, None, rows=1)

#Random Zoom
imgs = [random_zoom(img_arr, zoom_range=(1.5, 0.7), row_axis=0, col_axis=1, channel_axis=2, fill_mode='nearest') * 255 for _ in range(3)]
plot_images(imgs, None, rows=1)

#Random Greyscaling
imgs = [random_greyscale(img_arr, 0.1) * 255 for _ in range(3)]
plot_images(imgs, None, rows=1)

# %% [markdown]
# **Generating Augmented Images**
#
# Lets generate images for species for which only single image is given
